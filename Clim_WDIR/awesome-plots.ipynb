# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import xarray as xr
import os

# %%
filename = "tas_Amon_AWI-CM-1-1-MR_historical_r1i1p1f1_gn_185001-185012.nc"
dataset = xr.open_dataset(filename, decode_times=False)

# %%
dataset = xr.open_dataset("tas_Amon_AWI-CM-1-1-MR_historical_r1i1p1f1_gn_185001-185012.nc", decode_times=False)

# %%
dataset
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:    (time: 12, bnds: 2, lat: 192, lon: 384)
# Coordinates:
#   * time       (time) float64 96B 15.5 45.0 74.5 105.0 ... 288.5 319.0 349.5
#   * lat        (lat) float64 2kB -89.28 -88.36 -87.42 ... 87.42 88.36 89.28
#   * lon        (lon) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#     height     float64 8B ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) float64 192B ...
#     lat_bnds   (lat, bnds) float64 3kB ...
#     lon_bnds   (lon, bnds) float64 6kB ...
#     tas        (time, lat, lon) float32 4MB ...
# Attributes: (12/44)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  54421.0
#     creation_date:          2020-05-20T06:56:26Z
#     ...                     ...
#     title:                  AWI-CM-1-1-MR output prepared for CMIP6
# ...

# %%
array = np.array(dataset['tas'])

# %%
layer = array[0, :, :]
plt.imshow(layer)
# plt.savefig("0.png")

# %%
fig, ax = plt.subplots(4, 3, figsize=(40, 30))
for layer in range(12):
    row = layer // 3
    column = layer % 3
    
    ax[row, column].imshow(array[layer, ::-1, ::])
    
# fig.savefig("panel.png")
